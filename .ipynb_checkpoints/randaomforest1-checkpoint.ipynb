# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV

from tensorflow import keras
from tensorflow.keras.models import Sequential
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
# 데이터 불러오기
df = pd.read_csv('../superconductor/train.csv')

# %%
# 데이터 불러오기
test = pd.read_csv('../superconductor/test.csv')

# %%
df.head()
# Out:
#             ID  number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0  TRAIN_00000                   3           0.42099               0.39479
# 1  TRAIN_00001                   4           0.34401               0.22868
# 2  TRAIN_00002                   4           0.34437               0.25134
# 3  TRAIN_00003                   2           0.43715               0.45117
# 4  TRAIN_00004                   4           0.18946               0.19625
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0            0.42310                0.40580              0.55107
# 1            0.26533                0.16498              0.60467
# 2            0.26510                0.16350              0.60353
# 3            0.44012                0.46167              0.34778
# 4            0.16067                0.17351              0.62604
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  ...  \
# ...

# %%
test.head()
# Out:
#            ID  number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0  TEST_00000                   3           0.55602               0.54457
# 1  TEST_00001                   2           0.76697               0.55837
# 2  TEST_00002                   4           0.20867               0.19500
# 3  TEST_00003                   5           0.29060               0.35036
# 4  TEST_00004                   3           0.32541               0.33714
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0            0.55474                0.55230              0.54959
# 1            0.73447                0.56201              0.32778
# 2            0.15129                0.13905              0.60707
# 3            0.19990                0.26913              0.65468
# 4            0.28417                0.30238              0.49712
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  ...  \
# ...

# %%
#critical_temp을 구하는 것

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12759 entries, 0 to 12758
# Data columns (total 83 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               12759 non-null  object
#  1   number_of_elements               12759 non-null  int64
#  2   mean_atomic_mass                 12759 non-null  float64
#  3   wtd_mean_atomic_mass             12759 non-null  float64
#  4   gmean_atomic_mass                12759 non-null  float64
#  5   wtd_gmean_atomic_mass            12759 non-null  float64
#  6   entropy_atomic_mass              12759 non-null  float64
#  7   wtd_entropy_atomic_mass          12759 non-null  float64
#  8   range_atomic_mass                12759 non-null  float64
#  9   wtd_range_atomic_mass            12759 non-null  float64
#  10  std_atomic_mass                  12759 non-null  float64
# ...

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# count        12759.000000      12759.000000          12759.000000
# mean             4.116388          0.399213              0.328101
# std              1.439978          0.146245              0.164699
# min              1.000000          0.000000              0.002560
# 25%              3.000000          0.325890              0.225855
# 50%              4.000000          0.386490              0.267310
# 75%              5.000000          0.463380              0.392830
# max              9.000000          1.000000              1.000000
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# count       12759.000000           12759.000000          12759.00000
# mean            0.323766               0.272710              0.58757
# std             0.151425               0.176247              0.18422
# min             0.001790               0.005960              0.00000
# ...

# %%
df = df.drop(['ID'], axis = 1)

# %%
df.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   3           0.42099               0.39479
# 1                   4           0.34401               0.22868
# 2                   4           0.34437               0.25134
# 3                   2           0.43715               0.45117
# 4                   4           0.18946               0.19625
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0            0.42310                0.40580              0.55107
# 1            0.26533                0.16498              0.60467
# 2            0.26510                0.16350              0.60353
# 3            0.44012                0.46167              0.34778
# 4            0.16067                0.17351              0.62604
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                  0.41532            0.10631                0.20542
# ...

# %%
test = test.drop(['ID'], axis = 1)

# %%
test.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   3           0.55602               0.54457
# 1                   2           0.76697               0.55837
# 2                   4           0.20867               0.19500
# 3                   5           0.29060               0.35036
# 4                   3           0.32541               0.33714
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0            0.55474                0.55230              0.54959
# 1            0.73447                0.56201              0.32778
# 2            0.15129                0.13905              0.60707
# 3            0.19990                0.26913              0.65468
# 4            0.28417                0.30238              0.49712
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                  0.41431            0.17892                0.32741
# ...

# %%
df.isna()
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   False             False                 False
# 1                   False             False                 False
# 2                   False             False                 False
# 3                   False             False                 False
# 4                   False             False                 False
# ...                   ...               ...                   ...
# 12754               False             False                 False
# 12755               False             False                 False
# 12756               False             False                 False
# 12757               False             False                 False
# 12758               False             False                 False
#
#        gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0                  False                  False                False
# ...

# %%
# min : 0.000320
# max : 185.000000

# %%
# 정규화하기
# MinMaxScaler 클래스 생성
scaler = MinMaxScaler()

# MinMaxScaler 클래스의 fit_transform() 메서드 사용 데이터 정규화
normalized_data = scaler.fit_transform(df)

# 정규화된 데이터, 데이터 프레임으로 다시 변환
ndf = pd.DataFrame(normalized_data, columns=df.columns)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12759 entries, 0 to 12758
# Data columns (total 82 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number_of_elements               12759 non-null  float64
#  1   mean_atomic_mass                 12759 non-null  float64
#  2   wtd_mean_atomic_mass             12759 non-null  float64
#  3   gmean_atomic_mass                12759 non-null  float64
#  4   wtd_gmean_atomic_mass            12759 non-null  float64
#  5   entropy_atomic_mass              12759 non-null  float64
#  6   wtd_entropy_atomic_mass          12759 non-null  float64
#  7   range_atomic_mass                12759 non-null  float64
#  8   wtd_range_atomic_mass            12759 non-null  float64
#  9   std_atomic_mass                  12759 non-null  float64
#  10  wtd_std_atomic_mass              12759 non-null  float64
# ...

# %%
ndf.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0               0.250           0.42099              0.393237
# 1               0.375           0.34401              0.226700
# 2               0.375           0.34437              0.249419
# 3               0.125           0.43715              0.449761
# 4               0.375           0.18946              0.194187
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0           0.422065               0.402237              0.55107
# 1           0.264013               0.159973              0.60467
# 2           0.263782               0.158485              0.60353
# 3           0.439116               0.458442              0.34778
# 4           0.159165               0.168555              0.62604
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 0.418231            0.10631               0.207041
# ...

# %%
# 데이터 나누기
X = df.iloc[:, :-1]
y = df.iloc[:,[-1]]

# %%
X.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   3           0.42099               0.39479
# 1                   4           0.34401               0.22868
# 2                   4           0.34437               0.25134
# 3                   2           0.43715               0.45117
# 4                   4           0.18946               0.19625
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0            0.42310                0.40580              0.55107
# 1            0.26533                0.16498              0.60467
# 2            0.26510                0.16350              0.60353
# 3            0.44012                0.46167              0.34778
# 4            0.16067                0.17351              0.62604
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                  0.41532            0.10631                0.20542
# ...

# %%
y.head()
# Out:
#    critical_temp
# 0           5.69
# 1          43.60
# 2          39.00
# 3           6.20
# 4          16.30

# %%
model = RandomForestRegressor()

# %%
model.fit(X, y)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_584\2489992722.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X, y)
# RandomForestRegressor()

# %%
# 정규화하기
# MinMaxScaler 클래스 생성
scaler = MinMaxScaler()

# MinMaxScaler 클래스의 fit_transform() 메서드 사용 데이터 정규화
normalized_data = scaler.fit_transform(test)

# 정규화된 데이터, 데이터 프레임으로 다시 변환
tndf = pd.DataFrame(normalized_data, columns=test.columns)

# %%
test_pred = model.predict(tndf)

# %%
tndf['pred']=test_pred

# %%
# 역정규화
min_value = 0.000320
max_value = 185.000000
tndf['real_pred'] = tndf['pred'] * (max_value - min_value) + min_value

# %%
#제출
submission = pd.read_csv('../superconductor/sample_submission.csv')
submission['critical_temp'] = tndf['real_pred']
submission.head()
# Out:
#            ID  critical_temp
# 0  TEST_00000    5970.593289
# 1  TEST_00001     658.480913
# 2  TEST_00002    1626.970756
# 3  TEST_00003    2413.969415
# 4  TEST_00004    5591.544855

# %%
submission.to_csv('../superconductor/superconductor1.csv', index=  False)
